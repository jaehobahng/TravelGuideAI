# %% [markdown]
# # Read in data

# %%
import json

def read_json(filename, num_objects=3):
    with open(filename, 'r') as file:
        data = json.load(file)
        # Assuming the JSON data is a list of objects
        for i in range(min(num_objects, len(data))):
            print(data[i])

# Call the function with the filename and the number of objects to print
read_json('flight_activities_big.json', 5)
# Out:
# {'input': 'What are activities and flights from Kathmandu to JFK on Wednesday, July 26th? Can we have a Business Class ticket for two adults?', 'output': {'action': ['search_flights', 'activities'], 'action_input': {'origin': 'KTM', 'destination': 'UFA', 'departure_date': '2023-07-26', 'adults': 2, 'class': 'BUSINESS'}}}
# {'input': 'What is the cheapest flight from London to Paris on 2022-07-25 with a non-stop return?', 'output': {'action': ['search_flights', 'activities'], 'action_input': {'origin': 'LON', 'destination': 'PAR', 'departure_date': '2022-07-25', 'return_date': '2022-07-29', 'adults': 1, 'max': 5}}}
# {'input': 'flight from Seoul to Mumbai on january 1st', 'output': {'action': ['search_flights'], 'action_input': {'origin': 'SEL', 'destination': 'BOM', 'departure_date': '2023-01-01', 'adults': 2, 'max': 5}}}
# {'input': 'from London to Paris on 2022-07-15, how many non-stop flights are there? I have a family of four with two children.', 'output': {'action': ['search_flights', 'activities'], 'action_input': {'origin': 'LON', 'destination': 'PAR', 'departure_date': '2022-07-15', 'adults': 1, 'children': 2, 'infants': 0, 'class': '', 'nonStop': True, 'maxPrice': '', 'return_date': '', 'max': 5}}}
# {'input': 'I need a flight from MIA to HAV on 2024-03-25 with return on 2024-03-31 for 3 adults, 2 children, and want non-stop flights only.', 'output': {'action': ['search_flights', 'activities'], 'action_input': {'origin': 'MIA', 'destination': 'HAV', 'departure_date': '2024-03-25', 'return_date': '2024-03-31', 'adults': 3, 'children': 2, 'nonStop': True, 'max': 5}}}

# %% [markdown]
# # Adding diversity
#
# The two cells below have been ran iteratevely substitutting different cities to ensure the integrity of ourr data set and have sparse locations.

# %%
import json
from collections import Counter

def count_destinations(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
        # Initialize a list to store the destinations or origins
        destinations = []
        # Assuming the JSON data is a list of such dictionaries
        for item in data:
            # Ensure the nested keys exist before accessing them
            if 'output' in item and 'action_input' in item['output'] and 'origin' in item['output']['action_input']:
                destinations.append(item['output']['action_input']['origin'])
        # Count each unique destination
        destination_counts = Counter(destinations)
        return destination_counts

# Example usage:
destination_counts = count_destinations('Modified_Modified_Modified_Modified_Modified_Modified_Modified_Modified_Modified_flight_activities_big.json')
print(destination_counts)
# Out:
# Counter({'CDG': 61, 'MAD': 52, 'ORD': 34, 'SFO': 30, 'BOS': 21, 'PDX': 16, 'MNL': 16, 'BCN': 15, 'KRR': 15, 'BER': 13, 'BOM': 13, 'TYO': 13, 'AMS': 12, 'BRU': 12, 'STO': 12, 'CBR': 12, 'TUN': 12, 'PHC': 12, 'NCE': 12, 'ROM': 11, 'ATL': 11, 'HEL': 11, 'HND': 11, 'FRA': 11, 'BKK': 11, 'PHL': 11, 'SJU': 11, 'YKF': 11, 'PAP': 10, 'CPT': 10, 'IKT': 10, 'EDI': 10, 'GDL': 10, 'CHC': 10, 'ATH': 10, 'AKL': 10, 'PEK': 10, 'KTW': 10, 'PRG': 10, 'GEG': 10, 'SNN': 10, 'KIE': 9, 'SIN': 9, 'ODS': 9, 'ISB': 9, 'BUD': 9, 'KRT': 9, 'CPH': 9, 'BHD': 9, 'KBL': 9, 'MTY': 9, 'WLG': 9, 'AES': 9, 'PUS': 9, 'ITM': 9, 'MCO': 9, 'PBI': 9, 'SAN': 8, 'KMG': 8, 'OGZ': 8, 'HAN': 8, 'MSP': 8, 'LED': 8, 'MCX': 8, 'VRN': 8, 'DAL': 8, 'AUS': 8, 'KHV': 8, 'ASP': 8, 'MRV': 8, 'ROV': 8, 'SVG': 8, 'DTW': 8, 'MCI': 8, 'LBV': 8, 'PFO': 8, 'PER': 8, 'ICN': 8, 'ISF': 8, 'MCT': 8, 'CTU': 8, 'BJS': 8, 'KIX': 8, 'STN': 8, 'CSX': 8, 'ADL': 7, 'SYD': 7, 'VEN': 7, 'HCM': 7, 'PKC': 7, 'BKI': 7, 'SAW': 7, 'GLA': 7, 'KUL': 7, 'XIY': 7, 'PIS': 7, 'TPE': 7, 'CHN': 7, 'KGD': 7, 'BKO': 7, 'JAX': 7, 'KZN': 7, 'BNE': 7, 'LGB': 7, 'AER': 7, 'NAP': 7, 'SJC': 7, 'AAQ': 7, 'LOS': 7, 'GSP': 7, 'HRE': 7, 'PEN': 7, 'NUE': 7, 'CUN': 7, 'ABJ': 7, 'BGO': 7, 'YAM': 7, 'GMP': 7, 'SOF': 7, 'VNO': 7, 'PRN': 7, 'KIN': 7, 'DSM': 7, 'CHS': 7, 'MHD': 7, 'SZX': 7, 'SJD': 7, 'SAP': 7, 'POS': 7, 'BUR': 7, 'BZE': 7, 'PIT': 7, 'MHT': 7, 'FDF': 7, 'DVO': 7, 'KTM': 6, 'SEL': 6, 'OAK': 6, 'LYS': 6, 'PHX': 6, 'YQB': 6, 'IAH': 6, 'ULY': 6, 'DEL': 6, 'TJM': 6, 'TSF': 6, 'HKG': 6, 'VIE': 6, 'TBS': 6, 'PMO': 6, 'UFA': 6, 'HOU': 6, 'YTO': 6, 'LIS': 6, 'GOJ': 6, 'ZRH': 6, 'FLR': 6, 'YYT': 6, 'ALB': 6, 'WUH': 6, 'GUA': 6, 'YQR': 6, 'LGW': 6, 'KGL': 6, 'MIL': 6, 'YDF': 6, 'CEB': 6, 'GYM': 6, 'TRV': 6, 'EBB': 6, 'KHI': 6, 'ICT': 6, 'DBV': 6, 'COK': 6, 'GSO': 6, 'ZQN': 6, 'NRT': 6, 'PPT': 6, 'YUL': 6, 'SAV': 6, 'YOW': 6, 'VTE': 6, 'SJJ': 6, 'DHA': 5, 'ADD': 5, 'MUC': 5, 'DSA': 5, 'CTA': 5, 'PNH': 5, 'HTA': 5, 'GRU': 5, 'HMO': 5, 'LJU': 5, 'CAI': 5, 'MGA': 5, 'BDS': 5, 'HAV': 5, 'PTY': 5, 'CAG': 5, 'DEN': 5, 'LIM': 5, 'SCL': 5, 'LAS': 5, 'BUE': 5, 'JAK': 5, 'AAR': 5, 'TPA': 5, 'GOT': 5, 'GVA': 5, 'WRO': 5, 'SMF': 5, 'LEJ': 5, 'SAT': 5, 'WDH': 5, 'FUK': 5, 'COS': 5, 'KBV': 5, 'PVR': 5, 'NBO': 5, 'HGH': 5, 'BEY': 5, 'YHZ': 5, 'CTS': 5, 'TRD': 5, 'AMM': 5, 'RAR': 5, 'CMN': 5, 'SHJ': 5, 'DUD': 5, 'ALG': 5, 'ABQ': 5, 'RIC': 5, 'TGU': 5, 'BJM': 5, 'DOH': 5, 'SVQ': 5, 'RGN': 5, 'MEM': 5, 'ABV': 5, 'ROB': 5, 'CIA': 5, 'YHM': 5, 'TRN': 5, 'ARN': 5, 'MOW': 5, 'ORF': 5, 'BOI': 5, 'OOL': 5, 'YXS': 5, 'LGK': 5, 'RHO': 5, 'BWI': 5, 'CRK': 5, 'BTV': 5, 'AVV': 5, 'MVD': 5, 'KOL': 5, 'TIJ': 5, 'RUH': 5, 'PSP': 5, 'LPL': 5, 'BNA': 5, 'AUH': 5, 'SUF': 4, 'YYC': 4, 'HAM': 4, 'RIO': 4, 'OSL': 4, 'SVX': 4, 'EVN': 4, 'DUB': 4, 'KUF': 4, 'EMA': 4, 'SJO': 4, 'IST': 4, 'SIP': 4, 'JNB': 4, 'BOG': 4, 'OVB': 4, 'YEG': 4, 'DAR': 4, 'SHA': 4, 'DRS': 4, 'JIB': 4, 'OKA': 4, 'HER': 4, 'CKY': 4, 'HGA': 4, 'LCA': 4, 'YWG': 4, 'ACC': 4, 'FNA': 4, 'LIT': 4, 'BRN': 4, 'YYZ': 4, 'IJK': 4, 'ZNZ': 4, 'MLE': 4, 'LIN': 4, 'TAO': 4, 'LPQ': 4, 'SXM': 4, 'CWL': 4, 'JRO': 4, 'RDU': 4, 'NAN': 4, 'NCL': 4, 'YYJ': 4, 'GDN': 4, 'LST': 4, 'SPU': 4, 'BOJ': 4, 'VVO': 4, 'SDQ': 4, 'RNN': 4, 'THR': 4, 'REP': 4, 'APW': 4, 'TLS': 4, 'SEN': 4, 'MSY': 4, 'JED': 4, 'MBJ': 4, 'HBA': 4, 'SAL': 4, 'ASU': 4, 'MKE': 4, 'MDE': 4, 'MEL': 4, 'OKC': 4, 'CLT': 4, 'LTN': 4, 'KWI': 4, 'SNA': 4, 'BFS': 4, 'BLR': 4, 'LVI': 4, 'YVR': 4, 'MAN': 4, 'OPO': 4, 'KDH': 4, 'CNX': 4, 'BGW': 4, 'SEA': 3, 'DXB': 3, 'ALA': 3, 'YTZ': 3, '': 3, 'BGI': 3, 'CJU': 3, 'TUL': 3, 'PLZ': 3, 'IAD': 3, 'BLQ': 3, 'GRR': 3, 'COR': 3, 'RNO': 3, 'BRE': 3, 'MOG': 3, 'DCA': 3, 'ATQ': 3, 'TSV': 3, 'BHM': 3, 'HYD': 3, 'FCO': 3, 'BEL': 3, 'HKT': 3, 'PVG': 3, 'MLA': 3, 'MDL': 3, 'ZAG': 3, 'MEX': 3, 'PUJ': 3, 'PNQ': 3, 'UIO': 3, 'CLJ': 3, 'LIR': 3, 'BAH': 3, 'NKG': 3, 'OMA': 3, 'USM': 3, 'FIH': 3, 'GYE': 3, 'REC': 3, 'TIA': 3, 'BOD': 3, 'DLA': 3, 'VLC': 3, 'BEG': 3, 'LAX': 3, 'DMM': 3, 'BZV': 3, 'MXP': 3, 'CNS': 3, 'GOI': 2, 'TA ...

# %%
import json
import random

def replace_destination(filename):
    # Mapping of city codes to city names
    city_codes_to_names = {
    'PAR': 'Paris',
    'BCN': 'Barcelona',
    'SYD': 'Sydney',
    'LON': 'London',
    'FLR': 'Florence',
    'BER': 'Berlin',
    'MOW': 'Moscow',
    'BKK': 'Bangkok',
    'IST': 'Istanbul',
    'HND': 'Tokyo',
    'SIN': 'Singapore',
    'DXB': 'Dubai',
    'HKG': 'Hong Kong',
    'MAD': 'Madrid',
    'ROM': 'Rome',
    'CPT': 'Cape Town',
    'GRU': 'São Paulo',
    'BOM': 'Mumbai',
    'YTO': 'Toronto',
    'SEL': 'Seoul',
    'SHA': 'Shanghai',
    'MEX': 'Mexico City',
    'AMS': 'Amsterdam',
    'CAI': 'Cairo',
    'RIO': 'Rio de Janeiro',
    'LIS': 'Lisbon',
    'PRG': 'Prague',
    'BUD': 'Budapest',
    'BUE': 'Buenos Aires',
    'ATH': 'Athens',
    'DUB': 'Dublin',
    'OSL': 'Oslo',
    'STO': 'Stockholm',
    'HEL': 'Helsinki',
    'VIE': 'Vienna',
    'ZRH': 'Zurich',
    'MIL': 'Milan',
    'VEN': 'Venice',
    'NAP': 'Naples',
    'EDI': 'Edinburgh',
    'GLA': 'Glasgow',
    'MAN': 'Manchester',
    'BRU': 'Brussels',
    'WAR': 'Warsaw',
    'KIE': 'Kyiv',
    'TPE': 'Taipei',
    'KUL': 'Kuala Lumpur',
    'BNE': 'Brisbane',
    'PER': 'Perth',
    'AKL': 'Auckland',
    'WLG': 'Wellington',
    'JNB': 'Johannesburg',
    'DAR': 'Dar es Salaam',
    'ADD': 'Addis Ababa',
    'NBO': 'Nairobi',
    'LIM': 'Lima',
    'BOG': 'Bogotá',
    'SCL': 'Santiago',
    'HAV': 'Havana',
    'GDL': 'Guadalajara',
    'MNL': 'Manila',
    'HCM': 'Ho Chi Minh City',
    'HAN': 'Hanoi',
    'RGN': 'Yangon',
    'KTM': 'Kathmandu',
    'ISB': 'Islamabad',
    'KHI': 'Karachi',
    'DHA': 'Dhaka',
    'JAK': 'Jakarta',
    'DEL': 'Delhi',
    'CHN': 'Chennai',
    'KOL': 'Kolkata',
    'ASP': 'Alice Springs',
    'CBR': 'Canberra',
    'DAR': 'Darwin',
    'ADL': 'Adelaide',
    'PDX': 'Portland',
    'SEA': 'Seattle',
    'LAS': 'Las Vegas',
    'PHX': 'Phoenix',
    'SAN': 'San Diego',
    'DEN': 'Denver',
    'ATL': 'Atlanta',
    'MIA': 'Miami',
    'MSP': 'Minneapolis',
    'DTW': 'Detroit',
    'BOS': 'Boston',
    'PHL': 'Philadelphia',
    'ORD': 'Chicago',
    'LAX': 'Los Angeles',
    'NYC': 'New York City',
    'YVR': 'Vancouver',
    'YYC': 'Calgary',
    'YUL': 'Montreal',
    'YQB': 'Quebec City',
    'SFO': 'San Francisco',
    'IAH': 'Houston',
    'HOU': 'Houston',
    'DAL': 'Dallas',
    'AUS': 'Austin',
    'YEG': 'Edmonton',
    'YYZ': 'Toronto',
    'FRA': 'Frankfurt',
    'MUC': 'Munich',
    'GVA': 'Geneva',
    'LYS': 'Lyon',
    'BLQ': 'Bologna',
    'TSF': 'Treviso',
    'VRN': 'Verona',
    'BDS': 'Brindisi',
    'SUF': 'Lamezia Terme',
    'CAG': 'Cagliari',
    'PMO': 'Palermo',
    'CTA': 'Catania',
    'PIS': 'Pisa',
    'BLQ': 'Bologna',
    'SAW': 'Istanbul Sabiha Gökçen',
    'ALA': 'Almaty',
    'TAS': 'Tashkent',
    'EVN': 'Yerevan',
    'TBS': 'Tbilisi',
    'ODS': 'Odesa',
    'SIP': 'Simferopol',
    'LED': 'Saint Petersburg',
    'AAQ': 'Anapa',
    'KRR': 'Krasnodar',
    'SVX': 'Yekaterinburg',
    'OGZ': 'Vladikavkaz',
    'MCX': 'Makhachkala',
    'AER': 'Sochi',
    'MRV': 'Mineralnye Vody',
    'ROV': 'Rostov-on-Don',
    'KGD': 'Kaliningrad',
    'IJK': 'Izhevsk',
    'KZN': 'Kazan',
    'UFA': 'Ufa',
    'TJM': 'Tyumen',
    'OVB': 'Novosibirsk',
    'IKT': 'Irkutsk',
    'KHV': 'Khabarovsk',
    'VVO': 'Vladivostok',
    'PKC': 'Petropavlovsk-Kamchatsky',
    'HTA': 'Chita',
    'ULY': 'Ulyanovsk',
    'KUF': 'Samara',
    'GOJ': 'Nizhny Novgorod',
    'BEG': 'Belgrade',
    'SOF': 'Sofia',
    'ZAG': 'Zagreb',
    'LJU': 'Ljubljana',
    'RIX': 'Riga',
    'TLL': 'Tallinn',
    'VNO': 'Vilnius',
    'BLR': 'Bengaluru',
    'ABV': 'Abuja',
    'CMN': 'Casablanca',
    'DSS': 'Dakar',
    'LOS': 'Lagos',
    'ALG': 'Algiers',
    'TUN': 'Tunis',
    'KRT': 'Khartoum',
    'JIB': 'Djibouti',
    'RUH': 'Riyadh',
    'JED': 'Jeddah',
    'THR': 'Tehran',
    'BEY': 'Beirut',
    'DOH': 'Doha',
    'MCT': 'Muscat',
    'KWI': 'Kuwait City',
    'TYO': 'Tokyo (city)',
    'BJS': 'Beijing',
    'CAN': 'Guangzhou',
    'SZX': 'Shenzhen',
    'BKI': 'Kota Kinabalu',
    'REP': 'Siem Reap',
    'PNH': 'Phnom Penh',
    'MLE': 'Malé',
    'NAN': 'Nadi',
    'PPT': 'Papeete',
    'APW': 'Apia',
    'RAR': 'Rarotonga',
    'GRR': 'Grand Rapids',
    'CLT': 'Charlotte',
    'RDU': 'Raleigh',
    'BNA': 'Nashville',
    'MSY': 'New Orleans',
    'MCO': 'Orlando',
    'TPA': 'Tampa',
    'BWI': 'Baltimore',
    'IAD': 'Washington Dulles',
    'DCA': 'Washington DC (Reagan)',
    'CLE': 'Cleveland',
    'CVG': 'Cincinnati',
    'PIT': 'Pittsburgh',
    'YOW': 'Ottawa',
    'YHZ': 'Halifax',
    'YYT': 'St. John\'s',
    'CUN': 'Cancún',
    'GUA': 'Guatemala City',
    'SAP': 'San Pedro Sula',
    'SJO': 'San José (Costa Rica)',
    'PTY': 'Panama City',
    'UIO': 'Quito',
    'MTY': 'Monterrey',
    'PAP': 'Port-au-Prince',
    'SDQ': 'Santo Domingo',
    'PUJ': 'Punta Cana',
    'AMM': 'Amman',
    'BGW': 'Baghdad',
    'TLV': 'Tel Aviv',
    'AUH': 'Abu Dhabi',
    'CNX': 'Chiang Mai',
    'CEB': 'Cebu City',
    'DAD': 'Da Nang',
    'MCI': 'Kansas City',
    'STL': 'St. Louis',
    'MKE': 'Milwaukee',
    'OMA': 'Omaha',
    'TUL': 'Tulsa',
    'OKC': 'Oklahoma City',
    'ICT': 'Wichita',
    'BHM': 'Birmingham (Alabama)',
    'MEM': 'Memphis',
    'LIT': 'Little Rock',
    'DSM': 'Des Moines',
    'SAT': 'San Antonio',
    'MHT': 'Manchester (New Hampshire)',
    'BTV': 'Burlington (Vermont)',
    'ALB': 'Albany (New York)',
    'RIC': 'Richmond (Virginia)',
    'ORF': 'Norfolk',
    'GSO': 'Greensboro',
    'GSP': 'Greenville/Spartanburg',
    'CHS': 'Charleston (South Carolina)',
    'SAV': 'Savannah',
    'JAX': 'Jacksonville',
    'RSW': 'Fort Myers',
    'PBI': 'West Palm Beach',
    'RNO': 'Reno',
    'SMF': 'Sacramento',
    'BZN': 'Bozeman',
    'BOI': 'Boise',
    'GEG': 'Spokane',
    'TUS': 'Tucson',
    'ABQ': 'Albuquerque',
    'COS': 'Colorado Springs',
    'PSP': 'Palm Springs',
    'SJC': 'San Jose (California)',
    'OAK': 'Oakland',
    'SNA': 'Santa Ana (Orange County)',
    'BUR': 'Burbank',
    'LGB': 'Long Beach',
    'YHM': 'Hamilton',
    'YKF': 'Kitchener',
    'YXE': 'Saskatoon',
    'YQR': 'Regina',
    'YWG': 'Winnipeg',
    'YTZ': 'Toronto (Billy Bishop)',
    'YAM': 'Sault Ste. Marie',
    'YMM': 'Fort McMurray',
    'YDF': 'Deer Lake',
    'YYJ': 'Victoria',
    'YXS': 'Prince George',
    'PVR': 'Puerto Vallarta',
    'SJD': 'San José del Cabo',
    'GYM': 'Guaymas',
    'HMO': 'Hermosillo',
    'TIJ': 'Tijuana',
    'BZE': 'Belize City',
    'MGA': 'Managua',
    'SAL': 'San Salvador',
    'TGU': 'Tegucigalpa',
    'LIR': 'Liberia (Costa Rica)',
    'SXM': 'St. Maarten',
    'BGI': 'Bridgetown',
    'MBJ': 'Montego Bay',
    'KIN': 'Kingston',
    'POS': 'Port of Spain',
    'SJU': 'San Juan (Puerto Rico)',
    'FDF': 'Fort-de-France',
    'PTP': 'Pointe-à-Pitre',
    'MDE': 'Medellín',
    'GIG': 'Rio de Janeiro (Galeão)',
    'BEL': 'Belém',
    'REC': 'Recife',
    'COR': 'Córdoba (Argentina)',
    'MVD': 'Montevideo',
    'ASU': 'Asunción',
    'GYE': 'Guayaquil',
    'GDN': 'Gdańsk',
    'WRO': 'Wroclaw',
    'KTW': 'Katowice',
    'CLJ': 'Cluj-Napoca',
    'OTP': 'Bucharest (Otopeni)',
    'SKG': 'Thessaloniki',
    'RHO': 'Rhodes',
    'HER': 'Heraklion',
    'MLA': 'Malta',
    'TIA': 'Tirana',
    'BFS': 'Belfast (International)',
    'CWL': 'Cardiff',
    'BHX': 'Birmingham (UK)',
    'LPL': 'Liverpool',
    'NCL': 'Newcastle upon Tyne',
    'LBA': 'Leeds/Bradford',
    'DSA': 'Doncaster Sheffield',
    'EMA': 'East Midlands',
    'OPO': 'Porto',
    'SVQ': 'Seville',
    'VLC': 'Valencia',
    'PMI': 'Palma de Mallorca',
    'IBZ': 'Ibiza',
    'BSL': 'Basel',
    'BRN': 'Bern',
    'NUE': 'Nuremberg',
    'HAM': 'Hamburg',
    'DRS': 'Dresden',
    'LEJ': 'Leipzig',
    'BRE': 'Bremen',
    'MRS': 'Marseille',
    'NCE': 'Nice',
    'BOD': 'Bordeaux',
    'TLS': 'Toulouse',
    'TRN': 'Turin',
    'MXP': 'Milan Malpensa',
    'LIN': 'Milan Linate',
    'FCO': 'Rome Fiumicino',
    'CIA': 'Rome Ciampino',
    'LHR': 'London Heathrow',
    'LGW': 'London Gatwick',
    'STN': 'London Stansted',
    'LTN': 'London Luton',
    'SEN': 'London Southend',
    'SNN': 'Shannon',
    'BHD': 'Belfast City',
    'BGO': 'Bergen',
    'SVG': 'Stavanger',
    'TRD': 'Trondheim',
    'AES': 'Ålesund',
    'GOT': 'Gothenburg',
    'CPH': 'Copenhagen',
    'AAR': 'Aarhus',
    'RNN': 'Bornholm',
    'ARN': 'Stockholm Arlanda',
    'OUL': 'Oulu',
    'DBV': 'Dubrovnik',
    'SPU': 'Split',
    'VAR': 'Varna',
    'BOJ': 'Burgas',
    'PRN': 'Pristina',
    'SJJ': 'Sarajevo',
    'SKP': 'Skopje',
    'LCA': 'Larnaca',
    'PFO': 'Paphos',
    'MHD': 'Mashhad',
    'ISF': 'Isfahan',
    'DMM': 'Dammam',
    'BAH': 'Bahrain',
    'SHJ': 'Sharjah',
    'KBL': 'Kabul',
    'KDH': 'Kandahar',
    'DUR': 'Durban',
    'PLZ': 'Port Elizabeth',
    'ELS': 'East London (South Africa)',
    'WDH': 'Windhoek',
    'HRE': 'Harare',
    'LVI': 'Livingstone',
    'LUN': 'Lusaka',
    'JRO': 'Kilimanjaro',
    'ZNZ': 'Zanzibar',
    'EBB': 'Entebbe',
    'BJM': 'Bujumbura',
    'KGL': 'Kigali',
    'LBV': 'Libreville',
    'BZV': 'Brazzaville',
    'FIH': 'Kinshasa',
    'DLA': 'Douala',
    'BKO': 'Bamako',
    'CKY': 'Conakry',
    'FNA': 'Freetown',
    'ROB': 'Monrovia',
    'ABJ': 'Abidjan',
    'ACC': 'Accra',
    'KAN': 'Kano',
    'PHC': 'Port Harcourt',
    'HGA': 'Hargeisa',
    'MOG': 'Mogadishu',
    'PEK': 'Beijing',
    'PVG': 'Shanghai Pudong',
    'XMN': 'Xiamen',
    'CSX': 'Changsha',
    'CTU': 'Chengdu',
    'KMG': 'Kunming',
    'XIY': "Xi'an",
    'HGH': 'Hangzhou',
    'WUH': 'Wuhan',
    'NKG': 'Nanjing',
    'TAO': 'Qingdao',
    'CRK': 'Clark',
    'DVO': 'Davao',
    'KCH': 'Kuching',
    'PEN': 'Penang',
    'LGK': 'Langkawi',
    'HKT': 'Phuket',
    'USM': 'Ko Samui',
    'KBV': 'Krabi',
    'VTE': 'Vientiane',
    'LPQ': 'Luang Prabang',
    'MDL': 'Mandalay',
    'HYD': 'Hyderabad',
    'AMD': 'Ahmedabad',
    'GOI': 'Goa',
    'COK': 'Kochi',
    'TRV': 'Thiruvananthapuram',
    'ATQ': 'Amritsar',
    'PNQ': 'Pune',
    'TSA': 'Taipei Songshan',
    'NRT': 'Tokyo Narita',
    'KIX': 'Osaka Kansai',
    'ITM': 'Osaka Itami',
    'NGO': 'Nagoya',
    'CTS': 'Sapporo',
    'FUK': 'Fukuoka',
    'OKA': 'Okinawa',
    'ICN': 'Seoul Incheon',
    'GMP': 'Seoul Gimpo',
    'PUS': 'Busan',
    'CJU': 'Jeju',
    'MFM': 'Macau',
    'OOL': 'Gold Coast',
    'CNS': 'Cairns',
    'HBA': 'Hobart',
    'LST': 'Launceston',
    'MEL': 'Melbourne',
    'AVV': 'Avalon',
    'TSV': 'Townsville',
    'CHC': 'Christchurch',
    'DUD': 'Dunedin',
    'ZQN': 'Queenstown'
    }
    city_codes = [code for code in city_codes_to_names if code != 'LON']

    # Read the JSON file
    with open(filename, 'r') as file:
        data = json.load(file)

    # Iterate through each item in the data list
    for item in data:
        # Check if the 'output' and 'action_input' keys exist before attempting to access them
        if 'output' in item and 'action_input' in item['output']:
            action_inputs = item['output']['action_input']
            if 'origin' in action_inputs and action_inputs['origin'] == 'LON':
                new_city_code = random.choice(city_codes)  # Randomly choose a new city code
                action_inputs['origin'] = new_city_code  # Set the new city code as destination
                new_city_name = city_codes_to_names[new_city_code]
                # Replace 'New York' with a new city name in the input, accounting for case sensitivity
                item['input'] = item['input'].replace('Heathrow Airport', new_city_name).replace('heathrow airport', new_city_name).replace('LHR', new_city_code).replace('London', new_city_code).replace('LON', new_city_code).replace('london', new_city_code)

    with open('Modified_' + filename, 'w') as file:
        json.dump(data, file, indent=4)

# Example usage:
replace_destination('Modified_Modified_Modified_Modified_Modified_Modified_Modified_Modified_flight_activities_big.json')

# %% [markdown]
# # Adding all fields required to the output part of the data.

# %%
import json
def read_json(filename, num_objects=3):
    with open(filename, 'r') as file:
        data = json.load(file)
        # Assuming the JSON data is a list of objects
        for i in range(min(num_objects, len(data))):
            print(data[i])

# Call the function with the filename and the number of objects to print
read_json('flight_activities_big.json', 5)
# Out:
# {'input': 'What are activities and flights from Kathmandu to JFK on Wednesday, July 26th? Can we have a Business Class ticket for two adults?', 'output': {'action': ['search_flights', 'activities'], 'action_input': {'origin': 'KTM', 'destination': 'UFA', 'departure_date': '2023-07-26', 'adults': 2, 'class': 'BUSINESS'}}}
# {'input': 'What is the cheapest flight from ADL to Guayaquil on 2022-07-25 with a non-stop return?', 'output': {'action': ['search_flights', 'activities'], 'action_input': {'origin': 'ADL', 'destination': 'GYE', 'departure_date': '2022-07-25', 'return_date': '2022-07-29', 'adults': 1, 'max': 5}}}
# {'input': 'flight from Seoul to Mumbai on january 1st', 'output': {'action': ['search_flights'], 'action_input': {'origin': 'SEL', 'destination': 'BOM', 'departure_date': '2023-01-01', 'adults': 2, 'max': 5}}}
# {'input': 'from GOI to Geneva on 2022-07-15, how many non-stop flights are there? I have a family of four with two children.', 'output': {'action': ['search_flights', 'activities'], 'action_input': {'origin': 'GOI', 'destination': 'GVA', 'departure_date': '2022-07-15', 'adults': 1, 'children': 2, 'infants': 0, 'class': '', 'nonStop': True, 'maxPrice': '', 'return_date': '', 'max': 5}}}
# {'input': 'I need a flight from OAK to HAV on 2024-03-25 with return on 2024-03-31 for 3 adults, 2 children, and want non-stop flights only.', 'output': {'action': ['search_flights', 'activities'], 'action_input': {'origin': 'OAK', 'destination': 'HAV', 'departure_date': '2024-03-25', 'return_date': '2024-03-31', 'adults': 3, 'children': 2, 'nonStop': True, 'max': 5}}}

# %%
import json
from datetime import datetime

def is_valid_date(date_str):
    """Check if the date string is in 'YYYY-MM-DD' format."""
    if not isinstance(date_str, str):
        return False
    try:
        datetime.strptime(date_str, '%Y-%m-%d')
        return True
    except ValueError:
        return False

def ensure_correct_type(value, expected_data_type):
    """
    Ensure that the value is of the expected data type.
    If it's not, attempt to convert or fix it.
    """
    if expected_data_type == int:
        if isinstance(value, int):
            return value
        elif isinstance(value, float):
            return int(value)
        elif isinstance(value, list) and len(value) == 1:
            return ensure_correct_type(value[0], int)
        elif isinstance(value, str) and value.isdigit():
            return int(value)
        else:
            return None  # Return None for invalid int to handle maxPrice removal
    elif expected_data_type == str:
        if isinstance(value, str):
            return value
        elif isinstance(value, (int, float)):
            return str(value)
        elif isinstance(value, list) and len(value) == 1:
            return ensure_correct_type(value[0], str)
        else:
            return ''
    elif expected_data_type == bool:
        if isinstance(value, bool):
            return value
        elif isinstance(value, str):
            if value.lower() == 'true':
                return True
            elif value.lower() == 'false':
                return False
            else:
                return False
        else:
            return False
    elif expected_data_type == list:
        if isinstance(value, list):
            return value
        else:
            return []
    else:
        return value

def process_data(data):
    """
    Process each entry in the data list:
    - Check for required fields and validate them.
    - If optional fields are present, ensure they are in the correct format.
    - Do not add missing optional fields.
    - Exclude entries with missing or invalid required fields.
    - Handle 'maxPrice' according to the new requirement.
    """
    required_fields = {
        'action': list,  # Under 'output'
        'origin': str,   # Under 'action_input'
        'destination': str,  # Under 'action_input'
        'departure_date': str,  # Under 'action_input'
        'adults': int,  # Under 'action_input'
        'max': int,  # Under 'action_input'
    }

    optional_fields = {
        'return_date': '',      # Expected type: str
        'children': 0,          # Expected type: int
        'infants': 0,           # Expected type: int
        'class': '',            # Expected type: str
        'nonStop': False,       # Expected type: bool
        # 'maxPrice' is intentionally omitted from optional_fields
        #'ratings': 0,           # Expected type: int
        #'amenities': [],        # Expected type: list
        # 'max' is already included in required_fields
    }

    output_data = []
    for obj in data:
        valid = True

        # Check if 'output' and 'action_input' are present
        if 'output' not in obj or 'action_input' not in obj['output']:
            print('Missing output or action_input:', json.dumps(obj, indent=4))
            continue  # Skip this object

        # Check 'action' in obj['output']
        if 'action' not in obj['output']:
            print(f"Missing required field 'action':", json.dumps(obj, indent=4))
            continue  # Skip this object
        else:
            action_value = obj['output']['action']
            # Ensure 'action' is exactly ["search_flights", "search_hotels", "activities"]
            if action_value != ["search_flights", "activities"]:
                print(f"Invalid 'action' field:", json.dumps(obj, indent=4))
                continue  # Skip this object

        action_input = obj['output']['action_input']

        # Ensure 'action_input' is a dictionary
        if not isinstance(action_input, dict):
            print('action_input is not a dictionary:', json.dumps(obj, indent=4))
            continue

        # Check required fields under 'action_input'
        for field, expected_data_type in required_fields.items():
            if field == 'action':
                continue  # Already checked
            if field not in action_input:
                print(f"Missing required field '{field}':", json.dumps(obj, indent=4))
                valid = False
                break
            else:
                value = action_input[field]
                # Ensure the value is of the correct type and format
                if field == 'departure_date':
                    if not is_valid_date(value):
                        print(f"Invalid 'departure_date' format:", json.dumps(obj, indent=4))
                        valid = False
                        break
                elif field in ['origin', 'destination']:
                    action_input[field] = ensure_correct_type(value, str)
                    if not action_input[field]:
                        print(f"Invalid '{field}' value:", json.dumps(obj, indent=4))
                        valid = False
                        break
                else:
                    # Ensure correct data type
                    action_input[field] = ensure_correct_type(value, expected_data_type)

        if not valid:
            continue  # Skip this object

        # For optional fields that are present, ensure they are in the correct format
        for field in optional_fields.keys():
            if field in action_input and action_input[field] is not None:
                expected_data_type = type(optional_fields[field])
                action_input[field] = ensure_correct_type(action_input[field], expected_data_type)
                # Additional date validation for 'return_date'
                if field == 'return_date' and action_input[field]:
                    if not is_valid_date(action_input[field]):
                        print(f"Invalid 'return_date' format in field '{field}':", json.dumps(obj, indent=4))
                        action_input[field] = ''  # Reset to empty string or None, as per your preference

        # Handle 'maxPrice' according to your requirements
        if 'maxPrice' in action_input:
            max_price_value = ensure_correct_type(action_input['maxPrice'], int)
            if max_price_value is None or max_price_value == 0:
                # Remove 'maxPrice' if it's 0 or invalid
                del action_input['maxPrice']
            else:
                # Keep 'maxPrice' if it's greater than 0
                action_input['maxPrice'] = max_price_value

        # Append the validated and fixed object to the output list
        output_data.append(obj)

    return output_data

def main():
    """Main function to process the JSON data."""
    # Read data from 'Flight_Hotel_Activ.json'
    with open('flight_activities_big.json', 'r') as f:
        data = json.load(f)

    # Process the data
    processed_data = process_data(data)

    # Write the processed data to 'new.json'
    with open('flight_activities_big_clean.json', 'w') as f:
        json.dump(processed_data, f, indent=4)

    # Print the length of the new JSON
    print(f"Number of entries in new.json: {len(processed_data)}")

if __name__ == '__main__':
    main()
# Out:
# Missing required field 'max': {
#     "input": "What are activities and flights from Kathmandu to JFK on Wednesday, July 26th? Can we have a Business Class ticket for two adults?",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "KTM",
#             "destination": "UFA",
#             "departure_date": "2023-07-26",
#             "adults": 2,
#             "class": "BUSINESS"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Seoul to Mumbai on january 1st",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "SEL",
#             "destination": "BOM",
#             "departure_date": "2023-01-01",
#             "adults": 2,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "One way flight from Sydney to Barcelona on October 12th for two adults.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "SYD",
#             "destination": "BCN",
#             "departure_date": "2022-10-12",
#             "adults": 2,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "I would like a flight from Venice to Edmonton with my family on December 15th.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "VEN",
#             "destination": "YEG",
#             "departure_date": "2022-12-15",
#             "adults": 1,
#             "return_date": "",
#             "children": 0,
#             "infants": 0,
#             "class": "",
#             "nonStop": false,
#             "maxPrice": 1000000,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Book a flight from JFK to Brisbane on 2022-07-15 for me and my family.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "SAN",
#             "destination": "BNE",
#             "departure_date": "2022-07-15",
#             "adults": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Berlin to Kuwait City on 2022-07-15 with 1 adult, flight information only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "BER",
#             "destination": "KWI",
#             "departure_date": "2022-07-15",
#             "adults": 1,
#             "return_date": "",
#             "children": 0,
#             "infants": 0,
#             "class": "",
#             "nonStop": false,
#             "maxPrice": 0,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "What is information about a flight from Madrid (MAD) to Chicago (ORD) on 2022-07-15? I want economy class, no stop flights",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "MAD",
#             "destination": "ORD",
#             "departure_date": "2022-07-15",
#             "adults": 1,
#             "class": "ECONOMY",
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Chicago to Cape Town on Saturday 2024-02-03, non-stop only, economy class for two adults",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "ORD",
#             "destination": "CPT",
#             "departure_date": "2024-02-03",
#             "adults": 2,
#             "max": 5,
#             "class": "ECONOMY",
#             "nonStop": true
#         }
#     }
# }
# Missing required field 'max': {
#     "input": "Hello, I'd like to book a flight from Dhaka to Catania on Friday, May 27th with my family of four.",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "DHA",
#             "destination": "CTA",
#             "departure_date": "2022-05-27",
#             "adults": 1,
#             "children": 3
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "One-way flight from San Francisco to JFK on 2024-07-15 for 2 adults",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "max": 5,
#             "origin": "SFO",
#             "destination": "HAV",
#             "departure_date": "2024-07-15",
#             "adults": 2
#         }
#     }
# }
# Missing required field 'max': {
#     "input": "What activities are available in Hangzhou? I am looking for a flight from Barcelona to Hangzhou on August 15th, with a return on August 22nd, one adult, two children, economy class.",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "BCN",
#             "destination": "HGH",
#             "departure_date": "2023-08-15",
#             "return_date": "2023-08-22",
#             "adults": 1,
#             "children": 2,
#             "class": "ECONOMY"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "What is information on flights from Phoenix to JFK for tomorrow? I want economy class with two adults.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "destination": "CAI",
#             "origin": "PHX",
#             "departure_date": "2024-02-28",
#             "adults": 2,
#             "class": "ECONOMY",
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "How much does it cost for a flight from Minneapolis to Chennai on August 15th?",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "MSP",
#             "destination": "CHN",
#             "departure_date": "2023-08-15",
#             "adults": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Petropavlovsk-Kamchatsky to Pittsburgh on June 15th, non-stop flights only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "PKC",
#             "destination": "PIT",
#             "departure_date": "2023-06-15",
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Ulyanovsk, London, July 25th",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "ULY",
#             "destination": "LON",
#             "departure_date": "2023-07-25",
#             "adults": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flight from Brussels to MIA on Jan 1, 2024 with two adults",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "BRU",
#             "destination": "MIA",
#             "departure_date": "2024-01-01",
#             "adults": 2,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "I am flying from JFK to Makhachkala on January 15th, 2024.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "ATL",
#             "destination": "MCX",
#             "departure_date": "2024-01-15",
#             "adults": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Chita to Bangkok on July 25th for 2 adults",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "HTA",
#             "destination": "BKK",
#             "departure_date": "2023-07-25",
#             "adults": 2,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Istanbul Sabiha G\u00f6k\u00e7en to JFK on July 10, 2024 with 1 adult and non-stop flights only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "SAW",
#             "destination": "WAR",
#             "departure_date": "2024-07-10",
#             "adults": 1,
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from MUC to Philadelphia on May 15th, non-stop",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "MUC",
#             "destination": "PHL",
#             "departure_date": "2024-05-15",
#             "max": 5,
#             "nonStop": "true"
#         }
#     }
# }
# Missing required field 'max': {
#     "input": "What flights are available from Tyumen to Istanbul on June 10, 2024? How much does it cost for a family of four with two children under 2 years old?",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "TJM",
#             "destination": "IST",
#             "departure_date": "2024-06-10",
#             "adults": 2,
#             "children": 2,
#             "infants": 2
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "what flights do I have from Brussels to Manila on July 15?",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "BRU",
#             "destination": "MNL",
#             "departure_date": "2022-07-15",
#             "adults": 1,
#             "class": "",
#             "nonStop": "",
#             "maxPrice": "",
#             "return_date": "",
#             "children": "",
#             "infants": "",
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Yekaterinburg to Bremen",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "SVX",
#             "destination": "BRE",
#             "departure_date": "2024-03-16"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Austin to Gothenburg on 2022-09-01, non-stop flights only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "AUS",
#             "destination": "GOT",
#             "departure_date": "2022-09-01",
#             "adults": 1,
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "What flights are available from S\u00e3o Paulo to JFK on a specific day?",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "GRU",
#             "destination": "KHV",
#             "departure_date": "2023-07-22",
#             "adults": 1,
#             "return_date": "",
#             "children": "",
#             "infants": "",
#             "class": "",
#             "nonStop": "",
#             "maxPrice": "",
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "One way flight from Dublin to JFK on August 25th for two adults with economy class",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "DUB",
#             "destination": "ATL",
#             "departure_date": "2023-08-25",
#             "adults": 2,
#             "class": "ECONOMY",
#             "max": 5
#         }
#     }
# }
# Missing output or action_input: {
#     "input": "What is the flight duration from LAX to NYC on June 1st?"
# }
# Missing output or action_input: {
#     "input": "What activities and flights are available from LAX to JFK on 2024-03-15?"
# }
# Invalid 'action' field: {
#     "input": "One-way flight from JFK to MIA on July 1st, with one adult.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "VIE",
#             "destination": "MIA",
#             "departure_date": "2023-07-01",
#             "adults": 1
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Brussels to Venice on january 15th",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "BRU",
#             "destination": "VEN",
#             "departure_date": "2024-01-15",
#             "adults": 2,
#             "return_date": "",
#             "children": "",
#             "infants": "",
#             "class": "ECONOMY",
#             "nonStop": false,
#             "maxPrice": null,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flights from Dubai JFK to Catania Catania on 2022-09-01 for 1 adult, non-stop flights only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "DXB",
#             "destination": "CTA",
#             "departure_date": "2022-09-01",
#             "adults": 1,
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Managua to Amsterdam on July 25th for 2 adults",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "MGA",
#             "destination": "AMS",
#             "departure_date": "2023-07-25",
#             "adults": 2,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Rome JFK to Bangkok Bangkok on July 15th, non-stop.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "ROM",
#             "destination": "BKK",
#             "departure_date": "2023-07-15",
#             "adults": "1",
#             "max": "5"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from NY to LA on 2022-07-25",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "NY",
#             "destination": "LA",
#             "departure_date": "2022-07-25",
#             "adults": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "How much does a flight from Brindisi to JFK cost on 2022-09-01? I'm traveling with my spouse and would like to fly back on 2022-09-05.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "BDS",
#             "destination": "PER",
#             "departure_date": "2022-09-01",
#             "return_date": "2022-09-05",
#             "adults": 2,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flights from Dublin to Pisa on August 15th, non-stop only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "DUB",
#             "destination": "PIS",
#             "departure_date": "2023-08-15",
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Calgary JFK to Naples Naples on 2022-07-25 with a return on 2022-08-01 for 2 adults, 1 child, non-stop flights only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "YYC",
#             "destination": "NAP",
#             "departure_date": "2022-07-25",
#             "return_date": "2022-08-01",
#             "adults": 2,
#             "children": 1,
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Missing required field 'adults': {
#     "input": "What activities can I do in Havana on Friday, April 15th? Can you also find me a flight from HAV to DTW for that day?",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "HAV",
#             "destination": "DTW",
#             "departure_date": "2022-04-15"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flight from Palermo to JFK on Monday, non-stop only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "PMO",
#             "destination": "PHL",
#             "departure_date": "2023-08-21",
#             "adults": 1,
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Krasnodar to Rome on January 15, 2024",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "KRR",
#             "destination": "FCO",
#             "departure_date": "2024-01-15",
#             "adults": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Can you show me flights from Treviso (JFK) to Dhaka (Dhaka) on October 15th? I'd like a Premium Economy ticket for two adults.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "TSF",
#             "destination": "DHA",
#             "departure_date": "2023-10-15",
#             "adults": 2,
#             "class": "PREMIUM_ECONOMY"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from JFK to MIA on 2022-07-25, one way, ECONOMY class",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "ALA",
#             "destination": "MIA",
#             "departure_date": "2022-07-25",
#             "adults": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Ufa UFA to Rome FCO on 2024-03-16 with 2 adults, non-stop only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "UFA",
#             "destination": "FCO",
#             "departure_date": "2024-03-16",
#             "adults": "2",
#             "max": "5"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "One-way from JFK to Adelaide on 2022-01-15 with 1 adult",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "max": "5",
#             "origin": "DHA",
#             "departure_date": "2022-01-15",
#             "destination": "ADL",
#             "adults": "1"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flight from KRR to Rome on Friday, January 14th, for 2 adults.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "KRR",
#             "destination": "FCO",
#             "departure_date": "2024-01-14",
#             "adults": 2,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flights from Toronto (JFK) to Tokyo (HND) on 2024-04-15, for 2 adults",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "YTO",
#             "destination": "HND",
#             "departure_date": "2024-04-15",
#             "adults": 2,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Vladikavkaz to AKL on 2022-07-25",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "OGZ",
#             "destination": "AKL",
#             "departure_date": "2022-07-25",
#             "adults": "1",
#             "max": "5"
#         }
#     }
# }
# Missing required field 'max': {
#     "input": "What activities and flights are available from Kuala Lumpur to Bordeaux on Saturday? I'd like two adults traveling.",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "KUL",
#             "destination": "BOD",
#             "departure_date": "2023-06-17",
#             "adults": 2
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Kuala Lumpur to miami for two adults on march 15th, return on march 20th, non-stop flights only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "KUL",
#             "destination": "MIA",
#             "departure_date": "2023-03-15",
#             "return_date": "2023-03-20",
#             "adults": 2,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "One way flight from EMA to Khabarovsk on May 15th with two adults.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "EMA",
#             "destination": "KHV",
#             "departure_date": "2023-05-15",
#             "adults": 2,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Show me flights from Seattle (SEA) to Rome (FCO) on January 15th, 2024 with class ECONOMY.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "SEA",
#             "destination": "FCO",
#             "departure_date": "2024-01-15",
#             "adults": "1",
#             "class": "ECONOMY",
#             "max": "5"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flight from Pisa to JFK on 2024-03-16",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "PIS",
#             "destination": "PHL",
#             "departure_date": "2024-03-16",
#             "adults": "1",
#             "max": "5"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flights from Edinburgh to Izhevsk on 2024-03-15 with 2 adults",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "EDI",
#             "destination": "IJK",
#             "departure_date": "2024-03-15",
#             "adults": 2,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flight from Guadalajara to Berlin on January 1st, 2024 with two children and one infant.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "GDL",
#             "destination": "BER",
#             "departure_date": "2024-01-01",
#             "children": "2",
#             "infants": "1"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Chennai to Simferopol on January 10th next year, non-stop",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "CHN",
#             "destination": "SIP",
#             "departure_date": "2024-01-10",
#             "adults": 1,
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "I am looking for flights from Istanbul Sabiha G\u00f6k\u00e7en to JFK on 2022-07-25.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "SAW",
#             "destination": "AAQ",
#             "departure_date": "2022-07-25",
#             "adults": "1",
#             "max": "5"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from San Francisco (SFO) to Santiago (SCL), departing on March 15th, 2024 with two adults.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "SFO",
#             "destination": "SCL",
#             "departure_date": "2024-03-15",
#             "adults": 2,
#             "max": 5
#         }
#     }
# }
# Invalid 'origin' value: {
#     "input": "What activities can I do at the airport in Dallas on June 15th?",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "",
#             "destination": "DAL",
#             "departure_date": "2023-06-15",
#             "adults": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flights from ODS to Perth on June 15, 2024, for 2 adults.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "ODS",
#             "destination": "PER",
#             "departure_date": "2024-06-15",
#             "adults": "2"
#         }
#     }
# }
# Missing required field 'max': {
#     "input": "How much will it cost for a flight from NYC to CHC on 2024-03-16 with my family? We need 2 adults, 1 child, and 1 infant.\nAlso, provide activities around Havana.",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "CHC",
#             "destination": "HAV",
#             "departure_date": "2024-03-16",
#             "adults": 2,
#             "children": 1,
#             "infants": 1
#         }
#     }
# }
# Missing required field 'adults': {
#     "input": "What's available for Manila to Nice, June 15th, non-stop flights only, first class?",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "MNL",
#             "destination": "NCE",
#             "departure_date": "2024-06-15",
#             "class": "",
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flights from Frankfurt to Rome on July 15th with 2 adults",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "FRA",
#             "destination": "FCO",
#             "departure_date": "2023-07-15",
#             "adults": 2,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "What is the cheapest non-stop flight from JFK to Odesa on 2024-03-17?",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "UFA",
#             "destination": "ODS",
#             "departure_date": "2024-03-17",
#             "max": 5,
#             "nonStop": true
#         }
#     }
# }
# Missing required field 'max': {
#     "input": "Flights from SJO to Phoenix on July 15th, non-stop only",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "SJO",
#             "destination": "PHX",
#             "departure_date": "2024-07-15",
#             "adults": 1,
#             "nonStop": true
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Istanbul to Port Elizabeth on June 15th, non-stop only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "IST",
#             "destination": "PLZ",
#             "departure_date": "2023-06-15",
#             "adults": 1,
#             "max": 5,
#             "nonStop": true
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Barcelona (BCN) to Madrid (MAD) on August 12, non-stop flights only.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "BCN",
#             "destination": "MAD",
#             "departure_date": "2023-08-12",
#             "adults": 1,
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Austin to Tokyo, June 15th, economy class with max price of $1000",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "AUS",
#             "destination": "NRT",
#             "departure_date": "2023-06-15",
#             "adults": "1",
#             "class": "ECONOMY",
#             "maxPrice": "1000"
#         }
#     }
# }
# Missing output or action_input: {
#     "input": "flight and activities for Charleston",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "error": "Invalid city name"
#     }
# }
# Missing required field 'adults': {
#     "input": "flight from Rome J.F.K to Adelaide on June 15th, return June 22nd, economy class, only non-stop flights.",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "ROM",
#             "destination": "ADL",
#             "departure_date": "2024-06-15",
#             "return_date": "2024-06-22",
#             "class": "ECONOMY",
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flights from Vienna VIE to Lamezia Terme JFK on Monday, June 13th for 2 adults",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "VIE",
#             "destination": "SUF",
#             "departure_date": "2024-06-13",
#             "return_date": "",
#             "adults": 2,
#             "children": "",
#             "infants": "",
#             "class": "",
#             "nonStop": false,
#             "maxPrice": "",
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flight from NYC to Treviso, departing on Friday, March 19, 2024",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "NYC",
#             "destination": "TSF",
#             "departure_date": "2024-03-19",
#             "adults": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "how much does it cost to fly from PAR to Melbourne on January 15th?",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "PAR",
#             "destination": "MEL",
#             "departure_date": "2023-01-15",
#             "adults": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flights from EDI to Edinburgh on May 15th with 2 adults, non-stop flights",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "EDI",
#             "destination": "EDI",
#             "departure_date": "2023-05-15",
#             "adults": 2,
#             "nonStop": true
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flights from Johannesburg (JFK) to Tbilisi (TBS) on January 15th, 2024 with two children non-stop.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "JNB",
#             "destination": "TBS",
#             "departure_date": "2024-01-15",
#             "adults": "1",
#             "children": "2",
#             "nonStop": "true",
#             "max": "5"
#         }
#     }
# }
# Missing output or action_input: {
#     "input": "What's available for a flight from LAX to JFK on 2024-03-16?"
# }
# Invalid 'action' field: {
#     "input": "How much will a flight from JFK to Kazan cost on July 15th? Can we have two adults and one child?",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "AKL",
#             "destination": "KZN",
#             "departure_date": "2022-07-15",
#             "adults": 2,
#             "children": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flights from Almaty to Madrid on May 15th 2024",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "ALA",
#             "destination": "MAD",
#             "departure_date": "2024-05-15",
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Hong Kong JFK to Cagliari Cagliari on May 15th, non-stop only for 4 adults",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "HKG",
#             "destination": "CAG",
#             "departure_date": "2023-05-15",
#             "adults": "4",
#             "max": "5",
#             "nonStop": "true"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flights from CBR CBR to Dublin JFK on 2024-03-16",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "CBR",
#             "destination": "DUB",
#             "departure_date": "2024-03-16",
#             "adults": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "What is the cheapest flight from JAX to Yekaterinburg on 2024-02-27?",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "JAX",
#             "destination": "SVX",
#             "departure_date": "2024-02-27",
#             "adults": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flights from Phoenix to Bordeaux on June 12, non-stop only please.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "PHX",
#             "destination": "BOD",
#             "departure_date": "2024-06-12",
#             "max": 5,
#             "nonStop": true
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Krasnodar (KRR) to Barcelona (BCN) on June 15th, one adult.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "KRR",
#             "destination": "BCN",
#             "departure_date": "2023-06-15",
#             "adults": "1",
#             "return_date": "",
#             "children": "0",
#             "infants": "0",
#             "class": "",
#             "nonStop": false,
#             "maxPrice": 50000,
#             "max": "5"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flights from Ulyanovsk JFK to Miami MIA on July 25th with non-stop flights only for me",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "ULY",
#             "destination": "MIA",
#             "departure_date": "2023-07-25",
#             "adults": 1,
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Kazan (JFK) to Mexico City (Mexico City) on 2022-07-25",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "KZN",
#             "destination": "MEX",
#             "departure_date": "2022-07-25",
#             "adults": "1",
#             "max": "5"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Buenos Aires to OVB on June 20th, non-stop please",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "BUE",
#             "destination": "OVB",
#             "departure_date": "2024-06-20",
#             "max": 5,
#             "nonStop": "yes"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flight from Vladikavkaz to JFK on 2022-07-22",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "OGZ",
#             "destination": "DEL",
#             "departure_date": "2022-07-22",
#             "adults": "1",
#             "max": "5"
#         }
#     }
# }
# Missing output or action_input: {
#     "input": "what are activities near Paris Eiffel Tower, depart from Amsterdam Schiphol Airport to Paris CDG on July 15th?"
# }
# Invalid 'action' field: {
#     "input": "Flights from Madrid to Lisbon on January 1, 2024 for two adults",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "MAD",
#             "destination": "LIS",
#             "departure_date": "2024-01-01",
#             "adults": 2,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "One-way flight from Houston (JFK) to Wellington (Wellington) on August 15, 2024.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "IAH",
#             "destination": "WLG",
#             "departure_date": "2024-08-15",
#             "adults": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Rome Rome to Verona JFK on August 12th, non-stop only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "ROM",
#             "destination": "VRN",
#             "departure_date": "2022-08-12",
#             "max": 5,
#             "nonStop": true
#         }
#     }
# }
# Missing output or action_input: {
#     "input": "Can you book a trip for me from LAX to JFK?",
#     "output": {
#         "action": "book_flight",
#         "parameters": {},
#         "utterance": "Can you book a trip for me from LAX to JFK?"
#     }
# }
# Invalid 'action' field: {
#     "input": "I am looking for flights from Bogot\u00e1 to JFK on August 12th with one adult, only non-stop flights and a maximum price of $500.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "BOG",
#             "destination": "CHN",
#             "departure_date": "2023-08-12",
#             "adults": 1,
#             "max": 5,
#             "nonStop": true,
#             "maxPrice": 500
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flights from Auckland AKL to Barcelona BCN on July 15th for 2 people, economy class.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "AKL",
#             "destination": "BCN",
#             "departure_date": "2023-07-15",
#             "adults": "2",
#             "class": "ECONOMY",
#             "max": "5"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flight from Seattle to London on August 10th, non-stop flights only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "SEA",
#             "destination": "LON",
#             "departure_date": "2024-08-10",
#             "adults": "1",
#             "nonStop": true,
#             "max": "5"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Khabarovsk to Rome on August 15, 2024 for two adults",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "KHV",
#             "destination": "FCO",
#             "departure_date": "2024-08-15",
#             "adults": 2,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flight from Jakarta to Venice on May 15th, non-stop only for me",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "JAK",
#             "destination": "VEN",
#             "departure_date": "2023-05-15",
#             "adults": "1",
#             "max": "5"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flights from Edinburgh to Edinburgh on 2022-07-25",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "EDI",
#             "destination": "EDI",
#             "departure_date": "2022-07-25",
#             "adults": 1,
#             "max": 5
#         }
#     }
# }
# Missing required field 'adults': {
#     "input": "What activities are available in Rostov-on-Don, France? I am interested in a flight from Rostov-on-Don (ROV) to Cagliari (JFK) on 2024-06-15.",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "ROV",
#             "destination": "CAG",
#             "departure_date": "2024-06-15",
#             "max": 5
#         }
#     }
# }
# Missing required field 'max': {
#     "input": "I am looking for information on flights from Darwin to JFK on 2024-03-15, also I would like to know about activities at my destination.",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "DAR",
#             "destination": "HCM",
#             "departure_date": "2024-03-15",
#             "adults": 1
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Lisbon to Luang Prabang on 2022-07-15 with 2 adults and 1 child",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "LIS",
#             "destination": "LPQ",
#             "departure_date": "2022-07-15",
#             "adults": "2",
#             "children": "1"
#         }
#     }
# }
# Missing required field 'max': {
#     "input": "I am traveling from Shanghai (Shanghai) to Split City City (Split) on October 15th, 2022 with two adults.",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "SHA",
#             "destination": "SPU",
#             "departure_date": "2022-10-15",
#             "adults": 2
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flights from Phoenix to SYD on 2024-02-27 for 2 adults, non-stop only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "PHX",
#             "destination": "SYD",
#             "departure_date": "2024-02-27",
#             "adults": 2,
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flights from Helsinki to Ahmedabad on 2024-03-16",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "HEL",
#             "destination": "AMD",
#             "departure_date": "2024-03-16",
#             "adults": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "I want information about flights from JFK to Tyumen on March 15th, 2024.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "GDL",
#             "destination": "TJM",
#             "departure_date": "2024-03-15",
#             "adults": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flights from JFK to Lima on 2024-07-15, two adults, non-stop",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "GOJ",
#             "destination": "LIM",
#             "departure_date": "2024-07-15",
#             "adults": 2,
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Stockholm to Miami on June 15th with 2 adults and 1 child.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "STO",
#             "destination": "MIA",
#             "departure_date": "2023-06-15",
#             "adults": 2,
#             "children": 1,
#             "max": 5
#         }
#     }
# }
# Missing output or action_input: {
#     "input": "What activities and flight information is available from NYC to LAX on June 1st?"
# }
# Invalid 'action' field: {
#     "input": "flight from Simferopol to Miami on September 1st with 2 adults and a child",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "SIP",
#             "destination": "MIA",
#             "departure_date": "2023-09-01",
#             "adults": 2,
#             "children": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flights from Detroit DTW to Brindisi JFK on January 15th, 2024 for 2 adults only non-stop flights",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "DTW",
#             "destination": "BDS",
#             "departure_date": "2024-01-15",
#             "adults": 2,
#             "nonStop": "",
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "How much does it cost for a flight from Jakarta to JFK on May 12th?",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "JAK",
#             "destination": "YVR",
#             "departure_date": "2023-05-12",
#             "adults": "1",
#             "max": "5"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from Warsaw to TJM on August 15, 2024",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "WAR",
#             "destination": "TJM",
#             "departure_date": "2024-08-15",
#             "adults": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flight information from TUN to Oslo on Monday, June 10th with 2 adults.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "TUN",
#             "destination": "OSL",
#             "departure_date": "2019-06-10",
#             "adults": 2,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Book a non-stop flight from Paris (CDG) to Istanbul (Istanbul) for two adults on May 15th, 2024.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "CDG",
#             "destination": "IST",
#             "departure_date": "2024-05-15",
#             "adults": 2,
#             "nonStop": true
#         },
#         "max": 5
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from TPA to Amritsar on June 10, 2024 with 2 adults, class business, non-stop flights only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "TPA",
#             "destination": "ATQ",
#             "departure_date": "2024-06-10",
#             "adults": 2,
#             "class": "BUSINESS",
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Missing output or action_input: {
#     "input": "Can I get some flight information for a trip from New York (JFK) to Paris (CDG)? The trip is on July 15, 2024. Can you also include activities like visiting the Eiffel Tower? We are traveling with two adults and one child."
# }
# Missing required field 'max': {
#     "input": "I'm looking for a flight from Paris to Rome with one stop on 2024-03-20, can you also show me some activities in Rome?",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "CDG",
#             "destination": "FCO",
#             "departure_date": "2024-03-20",
#             "return_date": "",
#             "children": 0,
#             "infants": 0,
#             "class": "ECONOMY",
#             "nonStop": false,
#             "maxPrice": 1000,
#             "adults": 2
#         },
#         "max": 5
#     }
# }
# Invalid 'action' field: {
#     "input": "Flights from Barcelona to YTZ on February 27th, non-stop only, two adults, max $500",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "BCN",
#             "destination": "YTZ",
#             "departure_date": "2023-02-27",
#             "adults": 2,
#             "nonStop": true,
#             "maxPrice": 500,
#             "max": 5
#         }
#     }
# }
# Missing output or action_input: {
#     "input": "flight from New York to Los Angeles on June 15, 2024 with two adults and a child."
# }
# Missing output or action_input: {
#     "input": "Find flight from LAX to MEX on March 15th, return on March 22nd, economy class, non-stop, max price 1000"
# }
# Missing required field 'max': {
#     "input": "I am looking for information about activities and flights from GOT to Bogot\u00e1 on January 10th, 2024. There are two adults traveling. Please show only non-stop flights.",
#     "output": {
# ...
#         },
#         "max": 5
#     }
# }
# Missing output or action_input: {
#     "input": "I am looking for activities and flights from LAX to JFK on 2024-03-16 with two adults, one child, non-stop flights."
# }
# Invalid 'action' field: {
#     "input": "flight from Katowice to OMA on 2024-03-16, non-stop only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "KTW",
#             "destination": "OMA",
#             "departure_date": "2024-03-16",
#             "adults": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "One way flight from OAK to Qingdao on 2024-03-20 with no children, two adults and economy class.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "OAK",
#             "destination": "TAO",
#             "departure_date": "2024-03-20",
#             "adults": 2,
#             "class": "ECONOMY",
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flights from SOF to Quito on April 23rd for two adults non-stop.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "SOF",
#             "destination": "UIO",
#             "departure_date": "2024-04-23",
#             "adults": 2,
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Missing required field 'max': {
#     "input": "What activities and flights are available from Milan to SJD on 2022-07-15 with 2 adults, a child, non-stop flight only, in Business class, max price of 2000?",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "MIL",
#             "destination": "SJD",
#             "departure_date": "2022-07-15",
#             "adults": 2,
#             "children": 1,
#             "class": "BUSINESS",
#             "nonStop": true,
#             "maxPrice": 2000
#         }
#     }
# }
# Missing output or action_input: {
#     "input": "Search activities and flights from LHR to JFK on 2024-07-15, return on 2024-07-22, for 2 adults and 1 child."
# }
# Invalid 'action' field: {
#     "input": "How much does a flight from DEN to Addis Ababa on August 15th cost with two adults and one infant?",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "DEN",
#             "destination": "ADD",
#             "departure_date": "2023-08-15",
#             "adults": 2,
#             "infants": 1,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Requesting flight from RIO to St. Louis on 2022-07-25 with class economy, non-stop flights only, for 3 adults.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "RIO",
#             "destination": "STL",
#             "departure_date": "2022-07-25",
#             "adults": 3,
#             "class": "ECONOMY",
#             "nonStop": "",
#             "maxPrice": "",
#             "max": 5
#         }
#     }
# }
# Missing output or action_input: {
#     "input": "Find activities for two adults with a child and infant in economy class from London to Paris on July 1st, only non-stop flights, max price is 500."
# }
# Missing output or action_input: {
#     "input": "I need information on flights from LAX to JFK on a specific day, I have two adults, can you show me non-stop options?"
# }
# Invalid 'action' field: {
#     "input": "I'm looking for flights from AAQ to MCI on May 15th, with 2 adults. Please include premium economy and only non-stop flights.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "AAQ",
#             "destination": "MCI",
#             "departure_date": "2024-05-15",
#             "adults": 2,
#             "class": "PREMIUM_ECONOMY",
#             "nonStop": true
#         },
#         "max": 5
#     }
# }
# Invalid 'action' field: {
#     "input": "Flights from SXM to Changsha on March 12th for 2 adults, non-stop only.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "SXM",
#             "destination": "CSX",
#             "departure_date": "2024-03-12",
#             "adults": 2,
#             "nonStop": true
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "flight from CSX to MIA on 2024-03-20 with two adults, non-stop only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "CSX",
#             "destination": "MIA",
#             "departure_date": "2024-03-20",
#             "adults": 2,
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Missing output or action_input: {
#     "input": "How much does a flight from LAX to CDG on June 1st cost with a return on June 15th for two adults, three children, and one infant in economy class?"
# }
# Missing required field 'max': {
#     "input": "What activities are available in Paris, France on August 15th? How much does a flight from Kansas City (Kansas City) to GVA (GVA) cost if I'm traveling with my family of four on August 10th and return on August 20th?",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "GVA",
#             "destination": "MCI",
#             "departure_date": "2024-08-10",
#             "return_date": "2024-08-20",
#             "adults": 2,
#             "children": 1,
#             "infants": 1
#         },
#         "max": 5
#     }
# }
# Missing required field 'max': {
#     "input": "search for flights from ICT to MAD on 2024-03-25 with only non-stop flights, what activities are available in Madrid",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "ICT",
#             "destination": "MAD",
#             "departure_date": "2024-03-25",
#             "adults": 1,
#             "nonStop": "true"
#         }
#     }
# }
# Invalid 'origin' value: {
#     "input": "What activities are available at Makhachkala on July 15th? I'm traveling with my family, so please include kids' programs.",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "",
#             "destination": "MCX",
#             "departure_date": "2023-07-15",
#             "adults": 1,
#             "children": 2,
#             "infants": 0,
#             "class": ""
#         }
#     }
# }
# Missing required field 'max': {
#     "input": "Flight from BOS to NCL on March 15th, non-stop economy class for two adults.",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "BOS",
#             "destination": "NCL",
#             "departure_date": "2024-03-15",
#             "adults": 2,
#             "class": "ECONOMY",
#             "nonStop": true
#         },
#         "max": 5
#     }
# }
# Invalid 'action' field: {
#     "input": "Flights from ODS to UIO on 2024-03-16 with non-stop flights only for 2 adults.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "ODS",
#             "destination": "UIO",
#             "departure_date": "2024-03-16",
#             "max": "5",
#             "adults": "2",
#             "nonStop": true
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Flights from BCN to Pristina on March 12, 2024, non-stop only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "BCN",
#             "destination": "PRN",
#             "departure_date": "2024-03-12",
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "I would like to request flights from Anapa to ULY on July 15th, 2022, with two adults only non-stop flights",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "AAQ",
#             "destination": "ULY",
#             "departure_date": "2022-07-15",
#             "adults": "2",
#             "nonStop": "true",
#             "max": "5"
#         }
#     }
# }
# Missing output or action_input: {
#     "input": "What are the activities for Paris to New York on June 15? I have two adults and a child, flying economy non-stop."
# }
# Invalid 'action' field: {
#     "input": "Flights from NKG to OVB on July 25th, 2024 for two adults in economy class.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "NKG",
#             "destination": "OVB",
#             "departure_date": "2024-07-25",
#             "adults": 2,
#             "class": "ECONOMY"
#         },
#         "max": 5
#     }
# }
# Invalid 'action' field: {
#     "input": "Flights from SOF to SYD on September 1st, 2024, with two adults and one child.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "SOF",
#             "destination": "SYD",
#             "departure_date": "2024-09-01",
#             "adults": 2,
#             "children": 1
#         },
#         "max": 5
#     }
# }
# Invalid 'action' field: {
#     "input": "requesting flights from Minneapolis to PPT on December 10th, with only non-stop flights, return flight on Dec 17th, one adult and two children, in economy class",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "MSP",
#             "destination": "PPT",
#             "departure_date": "2022-12-10",
#             "return_date": "2022-12-17",
#             "adults": 1,
#             "children": 2,
#             "class": "ECONOMY",
#             "nonStop": true,
#             "max": 5
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "Show me flights from DOH to Marseille on April 15th, with two adults, no return trip, only non-stop flights.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "DOH",
#             "destination": "MRS",
#             "departure_date": "2024-04-15",
#             "adults": 2,
#             "nonStop": true
#         }
#     }
# }
# Missing output or action_input: {
#     "input": "flights from New York to London on 2024-03-15, return on 2024-03-22, economy class"
# }
# Missing output or action_input: {
#     "input": "Flight from JFK to LHR on a specific day, non-stop only."
# }
# Invalid 'action' field: {
#     "input": "Flights from ABV to GEG on October 15th, with two adults.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "ABV",
#             "destination": "GEG",
#             "departure_date": "2023-10-15",
#             "adults": "2"
#         }
#     }
# }
# Missing output or action_input: {
#     "input": "Can you show me activities and flights from MAD to LAX on 2024-03-15? I have two adults, a child, and want economy class only."
# }
# Missing output or action_input: {
#     "input": "flight from JFK to LHR on July 15th, no return, economy class for 2 adults only non-stop flights"
# }
# Invalid 'action' field: {
#     "input": "Amsterdam to Doha on Saturday with two adults in economy class and non-stop flights",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "AMS",
#             "destination": "DOH",
#             "departure_date": "2023-03-18",
#             "adults": 2,
#             "class": "ECONOMY",
#             "nonStop": "true"
#         },
#         "max": 5
#     }
# }
# Missing required field 'max': {
#     "input": "show me activities from SJJ to Philadelphia on January 10, 2024, with two adults, and only non-stop flights.",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "SJJ",
#             "destination": "PHL",
#             "departure_date": "2024-01-10",
#             "adults": 2,
#             "nonStop": "true"
#         }
#     }
# }
# Missing output or action_input: {
#     "input": "Search flights from New York JFK to London LHR on December 25th, for two adults, non-stop, with a maximum price of $1000."
# }
# Missing output or action_input: {
#     "input": "what activities are available for flights from LAX to JFK on 2022-07-25 with 1 adult, non-stop only?"
# }
# Invalid 'action' field: {
#     "input": "Flight from YYZ to BHM on 2024-03-15 with non-stop only, economy class for 2 adults",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "YYZ",
#             "destination": "BHM",
#             "departure_date": "2024-03-15",
#             "adults": 2,
#             "class": "ECONOMY",
#             "nonStop": true
#         },
#         "max": 5
#     }
# }
# Missing output or action_input: {
#     "input": "Flights from Los Angeles (LAX) to New York City (JFK) on January 15th, return on January 22nd, non-stop flights only."
# }
# Invalid 'action' field: {
#     "input": "Flight from Tehran to KTM on June 15th, non-stop economy class for two adults and one child with a budget of $1000.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "THR",
#             "destination": "KTM",
#             "departure_date": "2023-06-15",
#             "class": "ECONOMY",
#             "nonStop": true,
#             "adults": 2,
#             "children": 1,
#             "maxPrice": 1000
#         },
#         "max": 5
#     }
# }
# Invalid 'action' field: {
#     "input": "Information on flights from PUS to IBZ for tomorrow, with two adults, non-stop only, and a maximum price of $2000.",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "PUS",
#             "destination": "IBZ",
#             "departure_date": "2024-03-09",
#             "adults": "2",
#             "nonStop": "true",
#             "maxPrice": "2000",
#             "max": "5"
#         }
#     }
# }
# Invalid 'action' field: {
#     "input": "show me flights from LPQ to Guatemala City on 2024-03-16 for 2 adults, non-stop only",
#     "output": {
#         "action": [
#             "search_flights"
#         ],
#         "action_input": {
#             "origin": "LPQ",
#             "destination": "GUA",
#             "departure_date": "2024-03-16",
#             "adults": 2,
#             "nonStop": true
#         },
#         "max": 5
#     }
# }
# Missing output or action_input: {
#     "input": "Flight from LAX to NYC on July 12th, non-stop only."
# }
# Missing output or action_input: {
#     "input": "Request information about activities and flights from LAX to JFK on 2022-07-15 with 2 adults, return date 2022-08-05, class business."
# }
# Missing output or action_input: {
#     "input": "What activities and flights are available from LHR to JFK on July 15th for two adults with a maximum price of $500?"
# }
# Missing output or action_input: {
#     "input": "I would like information on activities and a flight from LAX to PAR for tomorrow, with 2 adults, in business class."
# }
# Missing required field 'max': {
#     "input": "Activities from AER to Stavanger on 2024-03-16, non-stop flights only.",
#     "output": {
#         "action": [
#             "search_flights",
#             "activities"
#         ],
#         "action_input": {
#             "origin": "AER",
#             "destination": "SVG",
#             "departure_date": "2024-03-16",
#             "adults": 1,
#             "nonStop": "true"
#         }
#     }
# }
# Missing output or action_input: {
#     "input": "Find activities and a flight from ORD to LAX on March 12th for 2 adults and 1 child, only non-stop flights, with a maximum price of $500."
# }
# Number of entries in new.json: 1245
