# %% [markdown]
# # Read in data

# %%
import json

def read_json(filename, num_objects=3):
    with open(filename, 'r') as file:
        data = json.load(file)
        # Assuming the JSON data is a list of objects
        for i in range(min(num_objects, len(data))):
            print(data[i])

# Call the function with the filename and the number of objects to print
read_json('Flight_Activ.json', 5)
# Out:
# {'input': 'Can you find me a flight from LAX to JFK on October 15th for 2 adults in Economy class and only non-stop flights? Also, suggest some activities to do in New York.', 'output': {'action': ['search_flights', 'activities'], 'action_input': {'origin': 'LAX', 'destination': 'JFK', 'departure_date': '2023-10-15', 'adults': 2, 'return_date': '', 'children': '', 'infants': '', 'class': 'ECONOMY', 'nonStop': True, 'maxPrice': '', 'max': 5}}}
# {'input': "I need to book a flight from LAX to JFK on October 15th for two adults, one child, and it's fine if it's not non-stop. Also, what are some fun things to do in New York on that day?", 'output': {'action': ['search_flights', 'activities'], 'action_input': {'origin': 'LAX', 'destination': 'JFK', 'departure_date': '2023-10-15', 'adults': 2, 'children': 1, 'infants': '', 'class': '', 'nonStop': False, 'maxPrice': '', 'return_date': '', 'max': 5}}}
# {'input': 'I need a flight from JFK to LAX on 2023-11-15 for 2 adults and 1 child, preferred in business class, and only non-stop. Also, suggest things to do in Los Angeles.', 'output': {'action': ['search_flights', 'activities'], 'action_input': {'origin': 'JFK', 'destination': 'LAX', 'departure_date': '2023-11-15', 'adults': 2, 'children': 1, 'infants': '', 'class': 'BUSINESS', 'nonStop': True, 'maxPrice': '', 'return_date': '', 'max': 5}}}
# {'input': "Can you find me a flight from LAX to JFK on April 15? I'm looking for economy class tickets for 2 adults and a child. What are some activities I can do in New York that day?", 'output': {'action': ['search_flights', 'activities'], 'action_input': {'origin': 'LAX', 'destination': 'JFK', 'departure_date': '2023-04-15', 'adults': 2, 'return_date': '', 'children': 1, 'infants': '', 'class': 'ECONOMY', 'nonStop': '', 'maxPrice': '', 'max': 5}}}
# {'input': 'I need a flight from New York (JFK) to Los Angeles (LAX) on March 15th for 2 adults, one child, in business class, and it must be non-stop. Also, can you recommend some activities in LA?', 'output': {'action': ['search_flights', 'activities'], 'action_input': {'origin': 'JFK', 'destination': 'LAX', 'departure_date': '2023-03-15', 'adults': 2, 'children': 1, 'infants': '', 'class': 'BUSINESS', 'nonStop': True, 'maxPrice': '', 'return_date': '', 'max': 5}}}

# %% [markdown]
# # Adding diversity
#
# The two cells below have been ran iteratevely substitutting different cities to ensure the integrity of ourr data set and have sparse locations.

# %%
import json
from collections import Counter

def count_destinations(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
        # Initialize a list to store the destinations or origins
        destinations = []
        # Assuming the JSON data is a list of such dictionaries
        for item in data:
            # Ensure the nested keys exist before accessing them
            if 'output' in item and 'action_input' in item['output'] and 'origin' in item['output']['action_input']:
                destinations.append(item['output']['action_input']['origin'])
        # Count each unique destination
        destination_counts = Counter(destinations)
        return destination_counts

# Example usage:
destination_counts = count_destinations('Modified_Modified_Modified_Flight_Activ.json')
print(destination_counts)
# Out:
# Counter({'TAS': 3, 'DHA': 3, 'AER': 3, 'KHI': 3, 'LIM': 2, 'HKG': 2, 'CTA': 2, 'YUL': 2, 'YYZ': 2, 'VEN': 2, 'ASP': 2, 'VVO': 2, 'CAI': 2, 'ADL': 2, 'LIS': 2, 'SAW': 2, 'YVR': 2, 'CBR': 2, 'SIN': 2, 'SIP': 2, 'ALA': 2, 'BNE': 2, 'KIE': 2, 'GVA': 2, 'MOW': 2, 'BCN': 2, 'LYS': 1, 'KZN': 1, 'LON': 1, 'STO': 1, 'ROV': 1, 'PHX': 1, 'MCX': 1, 'LED': 1, 'AUS': 1, 'ZRH': 1, 'KRR': 1, 'DEL': 1, 'ULY': 1, 'OGZ': 1, 'EVN': 1, 'SEA': 1, 'IST': 1, 'PRG': 1, 'PMO': 1, 'HAV': 1, 'ATH': 1, 'SAN': 1, 'NAP': 1, 'BUD': 1, 'HAN': 1, 'SFO': 1, 'MUC': 1, 'OSL': 1, 'TBS': 1, 'BOS': 1, 'FLR': 1, 'OVB': 1, 'JNB': 1, 'MRV': 1, 'GRU': 1, 'PHL': 1, 'PKC': 1, 'DAR': 1, 'BOM': 1, 'BKK': 1, 'RIO': 1, 'DUB': 1, 'AKL': 1, 'PDX': 1})

# %%
import json
import random

def replace_destination(filename):
    # Mapping of city codes to city names
    city_codes_to_names = {
    'PAR': 'Paris',
    'BCN': 'Barcelona',
    'SYD': 'Sydney',
    'LON': 'London',
    'FLR': 'Florence',
    'BER': 'Berlin',
    'MOW': 'Moscow',
    'BKK': 'Bangkok',
    'IST': 'Istanbul',
    'HND': 'Tokyo',
    'SIN': 'Singapore',
    'DXB': 'Dubai',
    'HKG': 'Hong Kong',
    'MAD': 'Madrid',
    'ROM': 'Rome',
    'CPT': 'Cape Town',
    'GRU': 'São Paulo',
    'BOM': 'Mumbai',
    'YTO': 'Toronto',
    'SEL': 'Seoul',
    'SHA': 'Shanghai',
    'MEX': 'Mexico City',
    'AMS': 'Amsterdam',
    'CAI': 'Cairo',
    'RIO': 'Rio de Janeiro',
    'LIS': 'Lisbon',
    'PRG': 'Prague',
    'BUD': 'Budapest',
    'BUE': 'Buenos Aires',
    'ATH': 'Athens',
    'DUB': 'Dublin',
    'OSL': 'Oslo',
    'STO': 'Stockholm',
    'HEL': 'Helsinki',
    'VIE': 'Vienna',
    'ZRH': 'Zurich',
    'MIL': 'Milan',
    'VEN': 'Venice',
    'NAP': 'Naples',
    'EDI': 'Edinburgh',
    'GLA': 'Glasgow',
    'MAN': 'Manchester',
    'BRU': 'Brussels',
    'WAR': 'Warsaw',
    'KIE': 'Kyiv',
    'TPE': 'Taipei',
    'KUL': 'Kuala Lumpur',
    'BNE': 'Brisbane',
    'PER': 'Perth',
    'AKL': 'Auckland',
    'WLG': 'Wellington',
    'JNB': 'Johannesburg',
    'DAR': 'Dar es Salaam',
    'ADD': 'Addis Ababa',
    'NBO': 'Nairobi',
    'LIM': 'Lima',
    'BOG': 'Bogotá',
    'SCL': 'Santiago',
    'HAV': 'Havana',
    'GDL': 'Guadalajara',
    'MNL': 'Manila',
    'HCM': 'Ho Chi Minh City',
    'HAN': 'Hanoi',
    'RGN': 'Yangon',
    'KTM': 'Kathmandu',
    'ISB': 'Islamabad',
    'KHI': 'Karachi',
    'DHA': 'Dhaka',
    'JAK': 'Jakarta',
    'DEL': 'Delhi',
    'CHN': 'Chennai',
    'KOL': 'Kolkata',
    'ASP': 'Alice Springs',
    'CBR': 'Canberra',
    'DAR': 'Darwin',
    'ADL': 'Adelaide',
    'PDX': 'Portland',
    'SEA': 'Seattle',
    'LAS': 'Las Vegas',
    'PHX': 'Phoenix',
    'SAN': 'San Diego',
    'DEN': 'Denver',
    'ATL': 'Atlanta',
    'MIA': 'Miami',
    'MSP': 'Minneapolis',
    'DTW': 'Detroit',
    'BOS': 'Boston',
    'PHL': 'Philadelphia',
    'ORD': 'Chicago',
    'LAX': 'Los Angeles',
    'NYC': 'New York City',
    'YVR': 'Vancouver',
    'YYC': 'Calgary',
    'YUL': 'Montreal',
    'YQB': 'Quebec City',
    'SFO': 'San Francisco',
    'IAH': 'Houston',
    'HOU': 'Houston',
    'DAL': 'Dallas',
    'AUS': 'Austin',
    'YEG': 'Edmonton',
    'YYZ': 'Toronto',
    'FRA': 'Frankfurt',
    'MUC': 'Munich',
    'GVA': 'Geneva',
    'LYS': 'Lyon',
    'BLQ': 'Bologna',
    'TSF': 'Treviso',
    'VRN': 'Verona',
    'BDS': 'Brindisi',
    'SUF': 'Lamezia Terme',
    'CAG': 'Cagliari',
    'PMO': 'Palermo',
    'CTA': 'Catania',
    'PIS': 'Pisa',
    'BLQ': 'Bologna',
    'SAW': 'Istanbul Sabiha Gökçen',
    'ALA': 'Almaty',
    'TAS': 'Tashkent',
    'EVN': 'Yerevan',
    'TBS': 'Tbilisi',
    'ODS': 'Odesa',
    'SIP': 'Simferopol',
    'LED': 'Saint Petersburg',
    'AAQ': 'Anapa',
    'KRR': 'Krasnodar',
    'SVX': 'Yekaterinburg',
    'OGZ': 'Vladikavkaz',
    'MCX': 'Makhachkala',
    'AER': 'Sochi',
    'MRV': 'Mineralnye Vody',
    'ROV': 'Rostov-on-Don',
    'KGD': 'Kaliningrad',
    'IJK': 'Izhevsk',
    'KZN': 'Kazan',
    'UFA': 'Ufa',
    'TJM': 'Tyumen',
    'OVB': 'Novosibirsk',
    'IKT': 'Irkutsk',
    'KHV': 'Khabarovsk',
    'VVO': 'Vladivostok',
    'PKC': 'Petropavlovsk-Kamchatsky',
    'HTA': 'Chita',
    'ULY': 'Ulyanovsk',
    'KUF': 'Samara',
    'GOJ': 'Nizhny Novgorod'
    }

    city_codes = [code for code in city_codes_to_names if code != 'LAX']

    # Read the JSON file
    with open(filename, 'r') as file:
        data = json.load(file)
    
    # Iterate through each item and replace 'PAR' with a new random city code and name for each item
    for item in data:
        if item['output']['action_input']['origin'] == 'LAX':  # Correct path according to JSON structure
            new_city_code = random.choice(city_codes)  # Randomly choose a new city code for each 'PAR'
            item['output']['action_input']['origin'] = new_city_code
            new_city_name = city_codes_to_names[new_city_code]
            # Replace 'Paris' with a new city name in the input, accounting for case sensitivity
            item['input'] = item['input'].replace('Los Angeles', new_city_name).replace('los angeles', new_city_name).replace('LAX', new_city_code)

    # Save the modified data back to the file or to a new file
    with open('Modified_' + filename, 'w') as file:
        json.dump(data, file, indent=4)

# Example usage:
replace_destination('Modified_Modified_Flight_Activ.json')
