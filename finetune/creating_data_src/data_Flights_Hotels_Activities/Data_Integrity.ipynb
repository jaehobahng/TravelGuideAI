# %% [markdown]
# # Read in data

# %%
import json

def read_json(filename, num_objects=3):
    with open(filename, 'r') as file:
        data = json.load(file)
        # Assuming the JSON data is a list of objects
        for i in range(min(num_objects, len(data))):
            print(data[i])

# Call the function with the filename and the number of objects to print
read_json('Flight_Hotel_Activ.json', 5)
# Out:
# {'input': "I need to book a flight from NYC to LAX on 2023-11-21 for two adults and one child. I'd prefer business class and only non-stop flights. I also want a 5-star hotel with a swimming pool and Wi-Fi, and activities around the area for the duration of my stay.", 'output': {'action': ['search_flights', 'search_hotels', 'activities'], 'action_input': {'origin': 'NYC', 'destination': 'LAX', 'departure_date': '2023-11-21', 'adults': 2, 'children': 1, 'class': 'BUSINESS', 'nonStop': True, 'ratings': 5, 'amenities': ['SWIMMING_POOL', 'WIFI'], 'max': 5}}}
# {'input': "I'd like to plan a trip from New York (JFK) to Los Angeles (LAX) departing on 2023-12-15. It's for 2 adults and 1 child, in economy class. I'd prefer non-stop flights. For hotels, I'm looking for a 4-star rating with a swimming pool and free Wi-Fi. Also, could you suggest some fun activities for the destination?", 'output': {'action': ['search_flights', 'search_hotels', 'activities'], 'action_input': {'origin': 'JFK', 'destination': 'LAX', 'departure_date': '2023-12-15', 'adults': 2, 'children': 1, 'class': 'ECONOMY', 'nonStop': True, 'ratings': 4, 'amenities': ['SWIMMING_POOL', 'WIFI'], 'max': 5}}}
# {'input': 'I need to plan a trip from New York (JFK) to Los Angeles (LAX) starting on 2023-12-10. I want to book flights, hotels, and activities for 2 adults and 1 child, preferably in business class. The hotel should have a swimming pool and WiFi, and I would like options for non-stop flights only.', 'output': {'action': ['search_flights', 'search_hotels', 'activities'], 'action_input': {'origin': 'JFK', 'destination': 'LAX', 'departure_date': '2023-12-10', 'adults': 2, 'children': 1, 'class': 'BUSINESS', 'nonStop': True, 'amenities': ['SWIMMING_POOL', 'WIFI'], 'max': 5}}}
# {'input': "I'm planning a trip from New York (JFK) to Paris (CDG) on 2023-11-15. I'll need flights in business class, non-stop if possible, for 2 adults and 1 child. I also want a hotel with at least 4 stars, a swimming pool, and free WiFi. Can you also recommend some activities in Paris during my stay?", 'output': {'action': ['search_flights', 'search_hotels', 'activities'], 'action_input': {'origin': 'JFK', 'destination': 'CDG', 'departure_date': '2023-11-15', 'adults': 2, 'children': 1, 'class': 'BUSINESS', 'nonStop': True, 'ratings': 4, 'amenities': ['SWIMMING_POOL', 'WIFI'], 'max': 5}}}
# {'input': "I'm planning a trip from New York (JFK) to Los Angeles (LAX) on December 15, 2023. I need a flight for two adults and one child, preferably in Business class with non-stop flights only. For accommodation, I'd like to book a hotel with a minimum 4-star rating, and amenities like a swimming pool and WiFi. Also, recommend local activities we can explore in Los Angeles.", 'output': {'action': ['search_flights', 'search_hotels', 'activities'], 'action_input': {'origin': 'JFK', 'destination': 'LAX', 'departure_date': '2023-12-15', 'adults': 2, 'children': 1, 'class': 'BUSINESS', 'nonStop': True, 'ratings': 4, 'amenities': ['SWIMMING_POOL', 'WIFI'], 'max': 5}}}

# %% [markdown]
# # Adding diversity
#
# The two cells below have been ran iteratevely substitutting different cities to ensure the integrity of ourr data set and have sparse locations.

# %%
import json
from collections import Counter

def count_destinations(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
        # Initialize a list to store the destinations or origins
        destinations = []
        # Assuming the JSON data is a list of such dictionaries
        for item in data:
            # Ensure the nested keys exist before accessing them
            if 'output' in item and 'action_input' in item['output'] and 'origin' in item['output']['action_input']:
                destinations.append(item['output']['action_input']['origin'])
        # Count each unique destination
        destination_counts = Counter(destinations)
        return destination_counts

# Example usage:
destination_counts = count_destinations('Modified_Modified_Modified_Flight_Hotel_Activ.json')
print(destination_counts)
# Out:
# Counter({'DTW': 3, 'FRA': 3, 'ALA': 3, 'CAG': 3, 'AER': 3, 'KOL': 3, 'VVO': 3, 'KUF': 2, 'YYZ': 2, 'PAR': 2, 'GDL': 2, 'SAW': 2, 'CPT': 2, 'KHI': 2, 'RGN': 2, 'YVR': 2, 'SVX': 2, 'CHN': 2, 'BUD': 2, 'IJK': 2, 'PER': 2, 'HTA': 2, 'GLA': 2, 'LED': 2, 'PHL': 2, 'SFO': 1, 'PMO': 1, 'IST': 1, 'TAS': 1, 'IKT': 1, 'HAV': 1, 'BKK': 1, 'KZN': 1, 'OVB': 1, 'BRU': 1, 'ASP': 1, 'EDI': 1, 'MIL': 1, 'TPE': 1, 'KHV': 1, 'BER': 1, 'DAR': 1, 'HEL': 1, 'MAN': 1, 'WLG': 1, 'YUL': 1, 'LAS': 1, 'HKG': 1, 'BOG': 1, 'DXB': 1, 'DAL': 1, 'BNE': 1, 'KTM': 1, 'YEG': 1, 'MAD': 1, 'HCM': 1, 'PIS': 1, 'YYC': 1, 'ADL': 1, 'STO': 1, 'PDX': 1, 'HND': 1, 'SYD': 1, 'BLQ': 1, 'ROV': 1, 'SIN': 1, 'VEN': 1, 'MIA': 1})

# %%
import json
import random

def replace_destination(filename):
    # Mapping of city codes to city names
    city_codes_to_names = {
    'PAR': 'Paris',
    'BCN': 'Barcelona',
    'SYD': 'Sydney',
    'LON': 'London',
    'FLR': 'Florence',
    'BER': 'Berlin',
    'MOW': 'Moscow',
    'BKK': 'Bangkok',
    'IST': 'Istanbul',
    'HND': 'Tokyo',
    'SIN': 'Singapore',
    'DXB': 'Dubai',
    'HKG': 'Hong Kong',
    'MAD': 'Madrid',
    'ROM': 'Rome',
    'CPT': 'Cape Town',
    'GRU': 'São Paulo',
    'BOM': 'Mumbai',
    'YTO': 'Toronto',
    'SEL': 'Seoul',
    'SHA': 'Shanghai',
    'MEX': 'Mexico City',
    'AMS': 'Amsterdam',
    'CAI': 'Cairo',
    'RIO': 'Rio de Janeiro',
    'LIS': 'Lisbon',
    'PRG': 'Prague',
    'BUD': 'Budapest',
    'BUE': 'Buenos Aires',
    'ATH': 'Athens',
    'DUB': 'Dublin',
    'OSL': 'Oslo',
    'STO': 'Stockholm',
    'HEL': 'Helsinki',
    'VIE': 'Vienna',
    'ZRH': 'Zurich',
    'MIL': 'Milan',
    'VEN': 'Venice',
    'NAP': 'Naples',
    'EDI': 'Edinburgh',
    'GLA': 'Glasgow',
    'MAN': 'Manchester',
    'BRU': 'Brussels',
    'WAR': 'Warsaw',
    'KIE': 'Kyiv',
    'TPE': 'Taipei',
    'KUL': 'Kuala Lumpur',
    'BNE': 'Brisbane',
    'PER': 'Perth',
    'AKL': 'Auckland',
    'WLG': 'Wellington',
    'JNB': 'Johannesburg',
    'DAR': 'Dar es Salaam',
    'ADD': 'Addis Ababa',
    'NBO': 'Nairobi',
    'LIM': 'Lima',
    'BOG': 'Bogotá',
    'SCL': 'Santiago',
    'HAV': 'Havana',
    'GDL': 'Guadalajara',
    'MNL': 'Manila',
    'HCM': 'Ho Chi Minh City',
    'HAN': 'Hanoi',
    'RGN': 'Yangon',
    'KTM': 'Kathmandu',
    'ISB': 'Islamabad',
    'KHI': 'Karachi',
    'DHA': 'Dhaka',
    'JAK': 'Jakarta',
    'DEL': 'Delhi',
    'CHN': 'Chennai',
    'KOL': 'Kolkata',
    'ASP': 'Alice Springs',
    'CBR': 'Canberra',
    'DAR': 'Darwin',
    'ADL': 'Adelaide',
    'PDX': 'Portland',
    'SEA': 'Seattle',
    'LAS': 'Las Vegas',
    'PHX': 'Phoenix',
    'SAN': 'San Diego',
    'DEN': 'Denver',
    'ATL': 'Atlanta',
    'MIA': 'Miami',
    'MSP': 'Minneapolis',
    'DTW': 'Detroit',
    'BOS': 'Boston',
    'PHL': 'Philadelphia',
    'ORD': 'Chicago',
    'LAX': 'Los Angeles',
    'NYC': 'New York City',
    'YVR': 'Vancouver',
    'YYC': 'Calgary',
    'YUL': 'Montreal',
    'YQB': 'Quebec City',
    'SFO': 'San Francisco',
    'IAH': 'Houston',
    'HOU': 'Houston',
    'DAL': 'Dallas',
    'AUS': 'Austin',
    'YEG': 'Edmonton',
    'YYZ': 'Toronto',
    'FRA': 'Frankfurt',
    'MUC': 'Munich',
    'GVA': 'Geneva',
    'LYS': 'Lyon',
    'BLQ': 'Bologna',
    'TSF': 'Treviso',
    'VRN': 'Verona',
    'BDS': 'Brindisi',
    'SUF': 'Lamezia Terme',
    'CAG': 'Cagliari',
    'PMO': 'Palermo',
    'CTA': 'Catania',
    'PIS': 'Pisa',
    'BLQ': 'Bologna',
    'SAW': 'Istanbul Sabiha Gökçen',
    'ALA': 'Almaty',
    'TAS': 'Tashkent',
    'EVN': 'Yerevan',
    'TBS': 'Tbilisi',
    'ODS': 'Odesa',
    'SIP': 'Simferopol',
    'LED': 'Saint Petersburg',
    'AAQ': 'Anapa',
    'KRR': 'Krasnodar',
    'SVX': 'Yekaterinburg',
    'OGZ': 'Vladikavkaz',
    'MCX': 'Makhachkala',
    'AER': 'Sochi',
    'MRV': 'Mineralnye Vody',
    'ROV': 'Rostov-on-Don',
    'KGD': 'Kaliningrad',
    'IJK': 'Izhevsk',
    'KZN': 'Kazan',
    'UFA': 'Ufa',
    'TJM': 'Tyumen',
    'OVB': 'Novosibirsk',
    'IKT': 'Irkutsk',
    'KHV': 'Khabarovsk',
    'VVO': 'Vladivostok',
    'PKC': 'Petropavlovsk-Kamchatsky',
    'HTA': 'Chita',
    'ULY': 'Ulyanovsk',
    'KUF': 'Samara',
    'GOJ': 'Nizhny Novgorod'
    }

    city_codes = [code for code in city_codes_to_names if code != 'LAX']

    # Read the JSON file
    with open(filename, 'r') as file:
        data = json.load(file)
    
    # Iterate through each item and replace 'PAR' with a new random city code and name for each item
    for item in data:
        if item['output']['action_input']['origin'] == 'LAX':  # Correct path according to JSON structure
            new_city_code = random.choice(city_codes)  # Randomly choose a new city code for each 'PAR'
            item['output']['action_input']['origin'] = new_city_code
            new_city_name = city_codes_to_names[new_city_code]
            # Replace 'Paris' with a new city name in the input, accounting for case sensitivity
            item['input'] = item['input'].replace('Los Angeles', new_city_name).replace('los angeles', new_city_name).replace('LAX', new_city_code)

    # Save the modified data back to the file or to a new file
    with open('Modified_' + filename, 'w') as file:
        json.dump(data, file, indent=4)

# Example usage:
replace_destination('Modified_Modified_Flight_Hotel_Activ.json')
